# %% [markdown]
# <a href="https://colab.research.google.com/github/payobe/cv_experiment/blob/main/rgb_%ED%8C%8C%EC%9D%BC_%EC%A1%B0%EC%9E%91%ED%95%B4%EB%B3%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import sys

# %%
img = cv.imread('climbing.jpeg')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x800>

# %%
cv2_imshow(img[0:img.shape[0]//2,0:img.shape[1]//2,:])
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %%
cv2_imshow(img[img.shape[0]//4:3*img.shape[0]//4,img.shape[1]//4:3*img.shape[1]//4])
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %%
cv2_imshow(img[:,:,0])
# Out:
# <PIL.Image.Image image mode=L size=600x800>

# %%
cv2_imshow(img[:,:,1])
# Out:
# <PIL.Image.Image image mode=L size=600x800>

# %%
cv2_imshow(img[:,:,2])
# Out:
# <PIL.Image.Image image mode=L size=600x800>

# %%
import matplotlib.pyplot as plt

# %%
h = cv.calcHist([img],[2],None,[256],[0,256])

# %%
plt.plot(h,color='r',linewidth=1)
