# %% [markdown]
# <a href="https://colab.research.google.com/github/payobe/cv_experiment/blob/main/%ED%8F%89%ED%99%9C%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv.imread("/content/drive/MyDrive/영상처리수업/mono1.jpg",cv.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1000x750>

# %%
img.shape
# Out:
# (750, 1000)

# %%
img2 = cv.equalizeHist(img)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=1000x750>
